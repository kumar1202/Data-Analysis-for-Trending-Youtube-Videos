# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_info = pd.read_csv("Test.csv")

# %%
df_info.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
df_info.shape
df_info.category_id
df_info['category_id'].value_counts()
# Out:
# 24    5
# 28    4
# 25    2
# 23    2
# 27    1
# 22    1
# 17    1
# 15    1
# 10    1
# 1     1
# Name: category_id, dtype: int64

# %%
df_info.groupby('category_id')['views',''].value_counts()
# Out:
# category_id  views
# 1            826059     1
# 10           687582     1
# 15           207532     1
# 17           81377      1
# 22           748374     1
# 23           295639     1
#              3191434    1
# 24           104578     1
#              343168     1
#              2095731    1
#              2103417    1
#              2418783    1
# 25           256426     1
#              544770     1
# 27           78044      1
# 28           75752      1
#              97007      1
#              119180     1
#              817732     1
# Name: views, dtype: int64

# %%
likes=df_info.likes
dislikes=df_info.dislikes
df_info['Ratio']=df_info.likes/df_info.dislikes
df_info.head(6)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
# 5  gHZ1Qz0KiKM      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
# 5                              2 Weeks with iPhone X               iJustine
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# ...

# %%
# df_info.index
df_info.reset_index().plot.bar(x='index',y='Ratio')
# you can always create a temporary DataFrame with the index as a column usinng
# df.reset_index()

# %%
dislikes=df_info.groupby('category_id').dislikes.value_counts()
dislikes
# Out:
# category_id  dislikes
# 1            119         1
# 10           1333        1
# 15           246         1
# 17           25          1
# 22           2966        1
# 23           638         1
#              5339        1
# 24           303         1
#              666         1
#              1989        1
#              2445        1
#              6146        1
# 25           1171        1
#              1363        1
# 27           53          1
# 28           36          1
#              52          1
#              511         1
#              778         1
# Name: dislikes, dtype: int64

# %%
v_df=df_info.groupby('category_id').views.sum().rename('total_views').\
reset_index().sort_values(by='total_views',ascending=False)
v_df
# Out:
#    category_id  total_views
# 6           24      7065677
# 5           23      3487073
# 9           28      1109671
# 0            1       826059
# 7           25       801196
# 4           22       748374
# 1           10       687582
# 2           15       207532
# 3           17        81377
# 8           27        78044

# %%
fig = v_df.plot.bar(x='category_id',y='total_views')
